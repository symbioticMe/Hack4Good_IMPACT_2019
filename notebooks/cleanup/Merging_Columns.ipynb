# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
# Reading the entire csv with all the sheets
big_data = pd.ExcelFile("data/raw/MM_for_nov17_aug19.xlsx")

# %%
# Sheet names
months = big_data.sheet_names

# %%
# List of columns that contains prices and are present for all months
columns_required = ["region", "q_gov", "q_district", "q_sbd",  "q_town",
                    "q_bread_price_per_8pieces", "q_bulgur_price_per_kilo", "q_chicken_price_per_kilo",
                    "q_eggs_price_per_30eggs", "q_potatoes_price_per_kilo", "q_tomatoes_price_per_kilo", 
                    "q_ghee_price_per_kilo", "q_oil_price_per_litre", "q_rlentils_price_per_kilo", 
                    "q_rice_price_per_kilo","q_salt_price_per_500g", "q_sugar_price_per_kilo", 
                    "q_tomatop_price_per_kilo", "q_onions_price_per_kilo", "q_cucumbers_price_per_kilo",
                    "q_isoap_price_per_piece", "q_lsoap_price_per_kilo", "q_dsoap_price_per_litre",
                    "q_spads_price_per_10pads", "q_toothp_price_per_100g", "q_sgas_price",
                    "q_mrkaz_price", "q_water_price_per_litre", "q_data_price_per_gb",
                    "q_rgpetrol_price", "q_mrpetrol_price", "q_rgdiesel_price", "q_mrdiesel_price",
                    "q_xrate_usdsyp_buy", "q_xrate_usdsyp_sell", "q_xrate_trysyp_buy",
                    "q_xrate_trysyp_sell", "q_xrate_jodsyp_buy", "q_xrate_jodsyp_sell",]

# %%
len(columns_required)
# Out:
# 39

# %%
months
# Out:
# ['Nov 17',
#  'Dec 17',
#  'Jan 18',
#  'Feb 18',
#  'March 18',
#  'April 18',
#  'May 18',
#  'June 18',
#  'July 18',
#  'Aug18',
#  'Sep 18',
#  'Oct 18',
#  'Nov 18',
#  'Dec 18',
#  'Jan 19',
#  'Feb 19',
#  'March 19',
#  'April 19',
#  'May 19',
#  'June 19',
#  'July 19',
#  'Aug 19']

# %%
# Creating an empty dataframe with all the required columns
df = pd.DataFrame(columns = columns_required)

# %%
# Creating a list of dataframe containing only the required columns for each month
df_months = []
for mon in months:
    n = len(big_data.parse(mon))
    month_col = [mon]*n
    df_mon = big_data.parse(mon)
    df_mon = df_mon[columns_required]
    df_mon['Month'] = month_col # adding column "Month" with repeated Month name
    df_months.append(df_mon)

# %%
len(big_data.parse('June 18'))
# Out:
# 2375

# %%
all_prices_df = pd.concat(df_months) # Merging all months into one

# %%
all_prices_df.reset_index(drop=True, inplace=True)

# %%
name_cols = ["admin1Name_en", "admin2Name_en", "admin3Name_en", "admin4Name_en"]
for col in name_cols:
    all_prices_df[col] = ""

# %% [markdown]
# ## Correcting town mapping to sub_districts, districts and govs

# %%
locations = pd.read_excel('data/raw/UNOCHA_pcodes_nocamps.xlsx', sheet_name = 'admin4')
all_towns = list(locations['admin4Pcode'])

# %%
for town in all_towns:
    # creating list of indexes with a particular town name
    idx1 = all_prices_df[all_prices_df['q_town'] == town].index
    n = len(idx1)
    # Certain towns may not be present in our data
    if n>0:
        # Assigning correct sbd, district and gov codes to the corresponding town
        idx2 = locations[locations['admin4Pcode'] == town].index[0]
        all_prices_df.loc[idx1, 'q_sbd'] = locations.loc[idx2, 'admin3Pcode']
        all_prices_df.loc[idx1, 'q_district'] = locations.loc[idx2, 'admin2Pcode']
        all_prices_df.loc[idx1, 'q_gov'] = locations.loc[idx2, 'admin1Pcode']
        # Adding town name
        all_prices_df.loc[idx1, 'admin4Name_en'] = locations.loc[idx2, 'admin4Name_en']

# %%
all_prices_df
# Out:
#           region q_gov q_district     q_sbd q_town q_bread_price_per_8pieces  \
# 0       besieged  SY03     SY0301  SY030105  C2314                   1644.44
# 1       besieged  SY03     SY0301  SY030105  C2314                   1644.44
# 2       besieged  SY03     SY0301  SY030105  C2314                   2044.44
# 3       besieged  SY03     SY0301  SY030105  C2314                       NaN
# 4       besieged  SY03     SY0301  SY030105  C2314                       NaN
# 5       besieged  SY03     SY0301  SY030105  C2314                       NaN
# 6       besieged  SY03     SY0301  SY030105  C2314                       NaN
# 7       besieged  SY03     SY0301  SY030105  C2314                       NaN
# 8       besieged  SY03     SY0301  SY030105  C2314                       NaN
# 9       besieged  SY03     SY0302  SY030200  C2338                   1644.44
# 10      besieged  SY03     SY0302  SY030200  C2338                   1688.89
# 11      besieged  SY03     SY0302  SY030200  C2338                   1644.44
# 12      besieged  SY03     SY0302  SY030200  C2338                       NaN
# 13      besieged  SY03     SY0302  SY030200  C2338                       NaN
# 14      besieged  SY03     SY0302  SY030200  C2338                       NaN
# 15      besieged  SY03     SY0302  SY030200  C2338                       NaN
# 16      besieged  SY03     SY0302  SY030200  C2338                       NaN
# 17      besieged  SY03     SY0302  SY030200  C2338                       NaN
# 18      besieged  SY03     SY0301  SY030105  C2314                       NaN
# 19      besieged  SY03     SY0301  SY030105  C2314                       NaN
# 20      besieged  SY03     SY0301  SY030105  C2314                       NaN
# 21      besieged  SY03     SY0301  SY030105  C2314                       NaN
# 22      besieged  SY03     SY0301  SY030105  C2314                       NaN
# 23      besieged  SY03     SY0301  SY030105  C2314                       NaN
# 24      besieged  SY03     SY0302  SY030200  C2338                       NaN
# 25      besieged  SY03     SY0302  SY030200  C2338                       NaN
# 26      besieged  SY03     SY0302  SY030200  C2338                       NaN
# 27      besieged  SY03     SY0302  SY030200  C2338                       NaN
# 28      besieged  SY03     SY0302  SY030200  C2338                       NaN
# 29      besieged  SY03     SY0302  SY030200  C2338                       NaN
# ...          ...   ...        ...       ...    ...                       ...
# 45985  northwest  SY07     SY0704  SY070402  C4238                       NaN
# 45986  northwest  SY07     SY0704  SY070402  C4238                       NaN
# 45987  northwest  SY07     SY0704  SY070402  C4238                       NaN
# 45988  northwest  SY07     SY0704  SY070402  C4238                       NaN
# 45989  northwest  SY07     SY0704  SY070402  C4238                       NaN
# 45990  northwest  SY07     SY0704  SY070402  C4238                       NaN
# 45991  northwest  SY07     SY0704  SY070402  C4238                       NaN
# 45992  northwest  SY07     SY0704  SY070402  C4238                       NaN
# 45993  northwest  SY07     SY0704  SY070402  C4238                       NaN
# 45994  northwest  SY07     SY0704  SY070402  C4238                       160
# 45995  northwest  SY07     SY0704  SY070402  C4238                       NaN
# 45996        NaN   NaN        NaN       NaN    NaN                       NaN
# 45997        NaN   NaN        NaN       NaN    NaN                       NaN
# 45998        NaN   NaN        NaN       NaN    NaN                       NaN
# 45999        NaN   NaN        NaN       NaN    NaN                       NaN
# 46000        NaN   NaN        NaN       NaN    NaN                       NaN
# 46001        NaN   NaN        NaN       NaN    NaN                       NaN
# 46002        NaN   NaN        NaN       NaN    NaN                       NaN
# 46003        NaN   NaN        NaN       NaN    NaN                       NaN
# 46004        NaN   NaN        NaN       NaN    NaN                       NaN
# 46005        NaN   NaN        NaN       NaN    NaN                       NaN
# 46006        NaN   NaN        NaN       NaN    NaN                       NaN
# 46007        NaN   NaN        NaN       NaN    NaN                       NaN
# 46008        NaN   NaN        NaN       NaN    NaN                       NaN
# 46009        NaN   NaN        NaN       NaN    NaN                       NaN
# 46010        NaN   NaN        NaN       NaN    NaN                       NaN
# 46011        NaN   NaN        NaN       NaN    NaN                       NaN
# 46012        NaN   NaN        NaN       NaN    NaN                       NaN
# 46013        NaN   NaN        NaN       NaN    NaN                       NaN
# 46014        NaN   NaN        NaN       NaN    NaN                       NaN
#
#       q_bulgur_price_per_kilo q_chicken_price_per_kilo  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
# 5                         NaN                      NaN
# 6                         NaN                      NaN
# 7                         NaN                      NaN
# 8                         NaN                      NaN
# 9                         NaN                      NaN
# 10                        NaN                      NaN
# 11                        NaN                      NaN
# 12                        NaN                      NaN
# 13                        NaN                      NaN
# 14                        NaN                      NaN
# 15                        NaN                      NaN
# 16                        NaN                      NaN
# 17                        NaN                      NaN
# 18                       4000                      NaN
# 19                       4200                      NaN
# 20                       4000                      NaN
# 21                        NaN                      NaN
# 22                        NaN                      NaN
# 23                        NaN                      NaN
# 24                       4000                      NaN
# 25                       4100                      NaN
# 26                       4200                      NaN
# 27                        NaN                      NaN
# 28                        NaN                      NaN
# 29                        NaN                      NaN
# ...                       ...                      ...
# 45985                     NaN                      NaN
# 45986                     NaN                      NaN
# 45987                     NaN                      NaN
# 45988                     NaN                      NaN
# 45989                     NaN                      NaN
# 45990                     NaN                      NaN
# 45991                     NaN                      NaN
# 45992                     NaN                      NaN
# 45993                     300                      NaN
# 45994                     300                      NaN
# 45995                     300                      NaN
# 45996                     NaN                      NaN
# 45997                     NaN                      NaN
# 45998                     NaN                      NaN
# 45999                     NaN                      NaN
# 46000                     NaN                      NaN
# 46001                     NaN                      NaN
# 46002                     NaN                      NaN
# 46003                     NaN                      NaN
# 46004                     NaN                      NaN
# 46005                     NaN                      NaN
# 46006                     NaN                      NaN
# 46007                     NaN                      NaN
# 46008                     NaN                      NaN
# 46009                     NaN                      NaN
# 46010                     NaN                      NaN
# 46011                     NaN                      NaN
# 46012                     NaN                      NaN
# 46013                     NaN                      NaN
# 46014                     NaN                      NaN
#
#       q_eggs_price_per_30eggs q_potatoes_price_per_kilo      ...       \
# 0                         NaN                       NaN      ...
# 1                         NaN                       NaN      ...
# 2                         NaN                       NaN      ...
# 3                         NaN                       NaN      ...
# 4                         NaN                       NaN      ...
# 5                         NaN                       NaN      ...
# 6                         NaN                       NaN      ...
# 7                         NaN                       NaN      ...
# 8                         NaN                       NaN      ...
# 9                         NaN                       NaN      ...
# 10                        NaN                       NaN      ...
# 11                        NaN                       NaN      ...
# 12                        NaN                       NaN      ...
# 13                        NaN                       NaN      ...
# 14                        NaN                       NaN      ...
# 15                        NaN                       NaN      ...
# 16                        NaN                       NaN      ...
# 17                        NaN                       NaN      ...
# 18                        NaN                       NaN      ...
# 19                      16500                       NaN      ...
# 20                      15000                       NaN      ...
# 21                        NaN                       NaN      ...
# 22                        NaN                       NaN      ...
# 23                        NaN                       NaN      ...
# 24                        NaN                       NaN      ...
# 25                        NaN                       NaN      ...
# 26                      16500                       NaN      ...
# 27                        NaN                       NaN      ...
# 28                        NaN                       NaN      ...
# 29                        NaN                       NaN      ...
# ...                       ...                       ...      ...
# 45985                     NaN                       NaN      ...
# 45986                     NaN                       NaN      ...
# 45987                     NaN                       NaN      ...
# 45988                     NaN                       200      ...
# 45989                     NaN                       200      ...
# 45990                     NaN                       NaN      ...
# 45991                     NaN                       NaN      ...
# 45992                     NaN                       NaN      ...
# 45993                    1100                       NaN      ...
# 45994                    1000                       200      ...
# 45995                    1000                       NaN      ...
# 45996                     NaN                       NaN      ...
# 45997                     NaN                       NaN      ...
# 45998                     NaN                       NaN      ...
# 45999                     NaN                       NaN      ...
# 46000                     NaN                       NaN      ...
# 46001                     NaN                       NaN      ...
# 46002                     NaN                       NaN      ...
# 46003                     NaN                       NaN      ...
# 46004                     NaN                       NaN      ...
# 46005                     NaN                       NaN      ...
# 46006                     NaN                       NaN      ...
# 46007                     NaN                       NaN      ...
# 46008                     NaN                       NaN      ...
# 46009                     NaN                       NaN      ...
# 46010                     NaN                       NaN      ...
# 46011                     NaN                       NaN      ...
# 46012                     NaN                       NaN      ...
# 46013                     NaN                       NaN      ...
# 46014                     NaN                       NaN      ...
#
#       q_xrate_usdsyp_sell q_xrate_trysyp_buy q_xrate_trysyp_sell  \
# 0                     NaN                NaN                 NaN
# 1                     NaN                NaN                 NaN
# 2                     NaN                NaN                 NaN
# 3                     NaN                NaN                 NaN
# 4                     NaN                NaN                 NaN
# 5                     NaN                NaN                 NaN
# 6                     NaN                NaN                 NaN
# 7                     NaN                NaN                 NaN
# 8                     NaN                NaN                 NaN
# 9                     NaN                NaN                 NaN
# 10                    NaN                NaN                 NaN
# 11                    NaN                NaN                 NaN
# 12                    NaN                NaN                 NaN
# 13                    NaN                NaN                 NaN
# 14                    NaN                NaN                 NaN
# 15                    NaN                NaN                 NaN
# 16                    NaN                NaN                 NaN
# 17                    NaN                NaN                 NaN
# 18                    NaN                NaN                 NaN
# 19                    NaN                NaN                 NaN
# 20                    NaN                NaN                 NaN
# 21                    NaN                NaN                 NaN
# 22                    NaN                NaN                 NaN
# 23                    NaN                NaN                 NaN
# 24                    NaN                NaN                 NaN
# 25                    NaN                NaN                 NaN
# 26                    NaN                NaN                 NaN
# 27                    NaN                NaN                 NaN
# 28                    NaN                NaN                 NaN
# 29                    NaN                NaN                 NaN
# ...                   ...                ...                 ...
# 45985                 NaN                NaN                 NaN
# 45986                 NaN                NaN                 NaN
# 45987                 NaN                NaN                 NaN
# 45988                 NaN                NaN                 NaN
# 45989                 NaN                NaN                 NaN
# 45990                 NaN                NaN                 NaN
# 45991                 NaN                NaN                 NaN
# 45992                 NaN                NaN                 NaN
# 45993                 NaN                NaN                 NaN
# 45994                 NaN                NaN                 NaN
# 45995                 NaN                NaN                 NaN
# 45996                 NaN                NaN                 NaN
# 45997                 NaN                NaN                 NaN
# 45998                 NaN                NaN                 NaN
# 45999                 NaN                NaN                 NaN
# 46000                 NaN                NaN                 NaN
# 46001                 NaN                NaN                 NaN
# 46002                 NaN                NaN                 NaN
# 46003                 NaN                NaN                 NaN
# 46004                 NaN                NaN                 NaN
# 46005                 NaN                NaN                 NaN
# 46006                 NaN                NaN                 NaN
# 46007                 NaN                NaN                 NaN
# 46008                 NaN                NaN                 NaN
# 46009                 NaN                NaN                 NaN
# 46010                 NaN                NaN                 NaN
# 46011                 NaN                NaN                 NaN
# 46012                 NaN                NaN                 NaN
# 46013                 NaN                NaN                 NaN
# 46014                 NaN                NaN                 NaN
#
#       q_xrate_jodsyp_buy q_xrate_jodsyp_sell   Month admin1Name_en  \
# 0                    NaN                 NaN  Nov 17
# 1                    NaN                 NaN  Nov 17
# 2                    NaN                 NaN  Nov 17
# 3                    NaN                 NaN  Nov 17
# 4                    NaN                 NaN  Nov 17
# 5                    NaN                 NaN  Nov 17
# 6                    NaN                 NaN  Nov 17
# 7                    NaN                 NaN  Nov 17
# 8                    NaN                 NaN  Nov 17
# 9                    NaN                 NaN  Nov 17
# 10                   NaN                 NaN  Nov 17
# 11                   NaN                 NaN  Nov 17
# 12                   NaN                 NaN  Nov 17
# 13                   NaN                 NaN  Nov 17
# 14                   NaN                 NaN  Nov 17
# 15                   NaN                 NaN  Nov 17
# 16                   NaN                 NaN  Nov 17
# 17                   NaN                 NaN  Nov 17
# 18                   NaN                 NaN  Nov 17
# 19                   NaN                 NaN  Nov 17
# 20                   NaN                 NaN  Nov 17
# 21                   NaN                 NaN  Nov 17
# 22                   NaN                 NaN  Nov 17
# 23                   NaN                 NaN  Nov 17
# 24                   NaN                 NaN  Nov 17
# 25                   NaN                 NaN  Nov 17
# 26                   NaN                 NaN  Nov 17
# 27                   NaN                 NaN  Nov 17
# 28                   NaN                 NaN  Nov 17
# 29                   NaN                 NaN  Nov 17
# ...                  ...                 ...     ...           ...
# 45985                NaN                 NaN  Aug 19
# 45986                NaN                 NaN  Aug 19
# 45987                NaN                 NaN  Aug 19
# 45988                NaN                 NaN  Aug 19
# 45989                NaN                 NaN  Aug 19
# 45990                NaN                 NaN  Aug 19
# 45991                NaN                 NaN  Aug 19
# 45992                NaN                 NaN  Aug 19
# 45993                NaN                 NaN  Aug 19
# 45994                NaN                 NaN  Aug 19
# 45995                NaN                 NaN  Aug 19
# 45996                NaN                 NaN  Aug 19
# 45997                NaN                 NaN  Aug 19
# 45998                NaN                 NaN  Aug 19
# 45999                NaN                 NaN  Aug 19
# 46000                NaN                 NaN  Aug 19
# 46001                NaN                 NaN  Aug 19
# 46002                NaN                 NaN  Aug 19
# 46003                NaN                 NaN  Aug 19
# 46004                NaN                 NaN  Aug 19
# 46005                NaN                 NaN  Aug 19
# 46006                NaN                 NaN  Aug 19
# 46007                NaN                 NaN  Aug 19
# 46008                NaN                 NaN  Aug 19
# 46009                NaN                 NaN  Aug 19
# 46010                NaN                 NaN  Aug 19
# 46011                NaN                 NaN  Aug 19
# 46012                NaN                 NaN  Aug 19
# 46013                NaN                 NaN  Aug 19
# 46014                NaN                 NaN  Aug 19
#
#       admin2Name_en admin3Name_en admin4Name_en
# 0                                         Saqba
# 1                                         Saqba
# 2                                         Saqba
# 3                                         Saqba
# 4                                         Saqba
# 5                                         Saqba
# 6                                         Saqba
# 7                                         Saqba
# 8                                         Saqba
# 9                                          Duma
# 10                                         Duma
# 11                                         Duma
# 12                                         Duma
# 13                                         Duma
# 14                                         Duma
# 15                                         Duma
# 16                                         Duma
# 17                                         Duma
# 18                                        Saqba
# 19                                        Saqba
# 20                                        Saqba
# 21                                        Saqba
# 22                                        Saqba
# 23                                        Saqba
# 24                                         Duma
# 25                                         Duma
# 26                                         Duma
# 27                                         Duma
# 28                                         Duma
# 29                                         Duma
# ...             ...           ...           ...
# 45985                                    Zarzur
# 45986                                    Zarzur
# 45987                                    Zarzur
# 45988                                    Zarzur
# 45989                                    Zarzur
# 45990                                    Zarzur
# 45991                                    Zarzur
# 45992                                    Zarzur
# 45993                                    Zarzur
# 45994                                    Zarzur
# 45995                                    Zarzur
# 45996
# 45997
# 45998
# 45999
# 46000
# 46001
# 46002
# 46003
# 46004
# 46005
# 46006
# 46007
# 46008
# 46009
# 46010
# 46011
# 46012
# 46013
# 46014
#
# [46015 rows x 44 columns]

# %%
## Adding names of sbd, districts and govs
all_sbd = list(locations['admin3Pcode'])
all_sbd = np.unique(all_sbd)
for sbd in all_sbd:
    idx1 = all_prices_df[all_prices_df['q_sbd'] == sbd].index
    n = len(idx1)
    # Certain sbds may not be present in our data
    if n>0:
        idx2 = locations[locations['admin3Pcode'] == sbd].index[0]
        all_prices_df.loc[idx1, 'admin1Name_en'] = locations.loc[idx2, 'admin1Name_en']
        all_prices_df.loc[idx1, 'admin2Name_en'] = locations.loc[idx2, 'admin2Name_en']
        all_prices_df.loc[idx1, 'admin3Name_en'] = locations.loc[idx2, 'admin3Name_en']

# %%
# Removing sbd that do not exists!
sbd_in_data = set(np.unique(list(all_prices_df["q_sbd"])))
sbd_nonexistent = sbd_in_data.difference(set(all_sbd))

sbd_nonexistent = sbd_nonexistent.difference({'nan'})

for sbd in sbd_nonexistent:
    idx = all_prices_df[all_prices_df['q_sbd'] == sbd].index
    print(idx)
    all_prices_df.drop(idx, inplace= True)

# %%
# Reordering columns
col_order = ["Month", "region", "q_gov", "admin1Name_en", "q_district", "admin2Name_en", "q_sbd",
             "admin3Name_en", "q_town", "admin4Name_en",
            "q_bread_price_per_8pieces", "q_bulgur_price_per_kilo", "q_chicken_price_per_kilo",
            "q_eggs_price_per_30eggs", "q_potatoes_price_per_kilo", "q_tomatoes_price_per_kilo", 
            "q_ghee_price_per_kilo", "q_oil_price_per_litre", "q_rlentils_price_per_kilo", 
            "q_rice_price_per_kilo","q_salt_price_per_500g", "q_sugar_price_per_kilo", 
            "q_tomatop_price_per_kilo", "q_onions_price_per_kilo", "q_cucumbers_price_per_kilo",
            "q_isoap_price_per_piece", "q_lsoap_price_per_kilo", "q_dsoap_price_per_litre",
            "q_spads_price_per_10pads", "q_toothp_price_per_100g", "q_sgas_price",
            "q_mrkaz_price", "q_water_price_per_litre", "q_data_price_per_gb",
            "q_rgpetrol_price", "q_mrpetrol_price", "q_rgdiesel_price", "q_mrdiesel_price",
            "q_xrate_usdsyp_buy", "q_xrate_usdsyp_sell", "q_xrate_trysyp_buy",
            "q_xrate_trysyp_sell", "q_xrate_jodsyp_buy", "q_xrate_jodsyp_sell",]

# %%
mydf = all_prices_df[col_order]
mydf.head()
# Out:
#     Month    region q_gov   admin1Name_en q_district   admin2Name_en  \
# 0  Nov 17  besieged  SY03  Rural Damascus     SY0301  Rural Damascus
# 1  Nov 17  besieged  SY03  Rural Damascus     SY0301  Rural Damascus
# 2  Nov 17  besieged  SY03  Rural Damascus     SY0301  Rural Damascus
# 3  Nov 17  besieged  SY03  Rural Damascus     SY0301  Rural Damascus
# 4  Nov 17  besieged  SY03  Rural Damascus     SY0301  Rural Damascus
#
#       q_sbd admin3Name_en q_town admin4Name_en         ...          \
# 0  SY030105    Kafr Batna  C2314         Saqba         ...
# 1  SY030105    Kafr Batna  C2314         Saqba         ...
# 2  SY030105    Kafr Batna  C2314         Saqba         ...
# 3  SY030105    Kafr Batna  C2314         Saqba         ...
# 4  SY030105    Kafr Batna  C2314         Saqba         ...
#
#   q_rgpetrol_price q_mrpetrol_price q_rgdiesel_price q_mrdiesel_price  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#   q_xrate_usdsyp_buy q_xrate_usdsyp_sell q_xrate_trysyp_buy  \
# 0                NaN                 NaN                NaN
# 1                NaN                 NaN                NaN
# 2                NaN                 NaN                NaN
# 3                NaN                 NaN                NaN
# 4                NaN                 NaN                NaN
#
#   q_xrate_trysyp_sell q_xrate_jodsyp_buy q_xrate_jodsyp_sell
# 0                 NaN                NaN                 NaN
# 1                 NaN                NaN                 NaN
# 2                 NaN                NaN                 NaN
# 3                 NaN                NaN                 NaN
# 4                 NaN                NaN                 NaN
#
# [5 rows x 44 columns]

# %%
# Removing entries of sbd that do not exist in their location mapping database (basically incorrect entry)
sbd_names = mydf['admin3Name_en'].values
sbd_names_cleaned = []
for i in sbd_names:
    s = re.sub('\W+', '', i)
    sbd_names_cleaned.append(s)

mydf['admin3Name_en'] = sbd_names_cleaned

# %%
# Converting empty string into NaN
all_cols = mydf.columns
for col in all_cols:
    if ("price" in col) | ("rate" in col):
        mydf[col] = list(mydf[col])

# %%
mydf.to_csv("data/processed/aggregated_monthly_1.csv")

# %%
# # Converting empty string into NaN
# n, d = all_prices_df.shape
# for i in range(n):
#     for j in range(d-6): # Removing the text columns
#         if type(all_prices_df.iloc[i,j])== str:
#             all_prices_df.iloc[i,j] = float('NaN')
